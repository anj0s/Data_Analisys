# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusanjos200203/Data_Analisys/blob/main/Analise_de_EDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# (

# %%
file_path = '/content/Compilado_A1.xlsx'

# %%
def read_EDS(file_path):

  Compilado = pd.ExcelFile(file_path)
  sheets_dict = {}

  for Sheet_Name in Compilado.sheet_names:
    sheet_info = Compilado.parse(Sheet_Name)
    sheets_dict[Sheet_Name] = sheet_info

  df = pd.concat(sheets_dict.values(), ignore_index = True)

  return df

# %%
a1_df = read_EDS(file_path)

# %%
a1_df
# Out:
#        Fe     K      O      C     Na     Mg     Al     Si      S     Cl  \
# 0    9.85  4.25  43.61   4.20   2.19   8.01  12.02  11.41   0.30   2.63
# 1    1.99  0.31  30.33   7.24  21.79   2.76   4.93   2.69    NaN  26.44
# 2    2.27  0.57  36.20   9.22  19.06   3.40   3.29   2.36   2.80  17.20
# 3    8.22  3.18  42.83   4.60   3.99  10.24  10.26   9.92   0.61   4.75
# 4   46.73  0.27  40.60   2.94   2.99   1.17   1.51   1.01   0.26   2.18
# 5    2.99  0.34  18.59  13.23  26.32    NaN          1.22    NaN  36.29
# 6   50.94  0.13  22.81   3.18   7.36   1.47   2.25   1.47   0.63   8.74
# 7   14.32  0.45  29.16  11.74  12.74   3.18   3.56   3.29   2.05  16.19
# 8    1.40  0.50  23.87  51.80   3.82   6.20   1.56   0.88   0.93   8.35
# 9    8.02  0.92  30.01  22.16   5.98  11.41   2.31   1.61   1.88  14.03
# 10   1.57  0.25  26.64  11.43  26.32    NaN    3.4   1.80    NaN  27.45
# 11  10.17  0.52  31.31  12.27  11.73   3.18   3.36   8.96   1.90  13.87
# 12  18.54  1.18  23.04   7.79   9.89   2.94   2.56   2.57   2.96  21.72
# 13   5.41  3.49  44.46   5.22   1.71  16.34   8.75  10.89   0.37   2.41
# 14   1.09   NaN  57.21   5.85   4.07   0.91   1.13   0.74  11.72   4.42
# 15  34.10  0.18  43.99   4.76   5.92   1.82   2.52   1.33   0.57   4.09
# 16   1.77  0.80  34.30  27.92   5.46  10.22   1.98   1.20   1.84  13.40
# 17  47.02  0.17  32.81   2.80   6.86   1.68   1.56   1.16   0.60   4.59
# 18  11.12  0.75  28.11   9.87  10.29   2.84   3.01   2.93   2.03  24.13
# 19   0.90  0.15  48.99   3.35   7.24    NaN     15  18.17   0.43   3.70
# 20  37.15   NaN  41.30   3.74   5.67   1.57   1.45   2.81   0.45   4.11
# 21  49.04  0.30  11.76   3.98  14.26   2.37   2.03   1.67   1.28  11.69
# 22   3.19  0.34  18.76   9.90  22.77   4.05   3.02   1.96   2.28  31.74
# 23   1.77  0.35  14.99    NaN  31.28    NaN          0.80    NaN  49.84
# 24   1.26  0.27  21.51  15.02  26.26    NaN    2.5   1.42   1.48  28.68
# 25  53.97  0.14  24.54   2.56   6.88   1.93   2.11   1.21   0.67   5.11
# 26   1.30  0.29  18.45   9.73  27.50    NaN   1.39   1.10    NaN  38.89
# 27   1.02  0.70  34.83  36.73   4.04  10.56    0.8   0.53   1.01   9.18
# 28   2.38  0.28  20.62  15.44  12.53    NaN   1.15   0.94   1.04  44.06
#
#        Ca    Ti     P
# 0     NaN  1.53   NaN
# 1    1.37  0.15   NaN
# 2    3.42  0.22   NaN
# 3     NaN  1.40   NaN
# 4    0.35   NaN   NaN
# 5    1.02   NaN   NaN
# 6    0.88  0.14   NaN
# 7    3.05  0.27   NaN
# 8    0.69   NaN   NaN
# 9    1.68   NaN   NaN
# 10   1.15   NaN   NaN
# 11   2.72   NaN   NaN
# 12   6.45  0.36   NaN
# 13    NaN  0.94   NaN
# 14  12.86   NaN   NaN
# 15   0.73   NaN   NaN
# 16   1.11   NaN   NaN
# 17   0.74   NaN   NaN
# 18   4.57  0.33   NaN
# 19   2.06   NaN
# 20   1.61   NaN  0.15
# 21   1.60   NaN
# 22   1.99   NaN
# 23   0.97   NaN
# 24   1.60   NaN   NaN
# 25   0.86   NaN   NaN
# 26   1.34   NaN   NaN
# 27   0.60   NaN   NaN
# 28   1.55   NaN   NaN
